# %% [markdown]
# <a href="https://colab.research.google.com/github/TshepisoMas/Python_programming/blob/main/codes/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **A Graduate Data Scientist in the Personal & Private Banking (PPB) division at Standard Bank.**
#
# ## Interview preparation:
#
#  In this project, I will be using seconary data from Kiggle.

# %% [markdown]
# # **PART 1: BUSINESS UNDERSTANDING**

# %% [markdown]
# # **Business Scenario**
#
# Over the past year, the bank has experienced a significant increase in loan applications. While this has driven business growth, it has also created operational challenges:
#
# Loan officers are taking longer to assess applications.
# Some low-risk customers are waiting unnecessarily for approval.
# A number of high-risk loans have resulted in defaults.
# Manual assessments can be inconsistent between loan officers.
#
# The Head of Credit Risk wants the bank to make lending decisions faster, more consistent, and more data-driven while maintaining responsible lending practices.
#
# The bank has historical data on previous loan applications, including:
#
# - Applicant demographics
# - Employment status
# - Monthly income
# - Credit score (CIBIL)
# - Existing debt obligations
# - Loan characteristics
# - Final loan decision (loan_status)
#
# Management believes that these historical records can be used to build a machine learning model that supports loan decision-making.

# %% [markdown]
# ## **Business Problem Statement**
#
# Develop a machine learning model that ***predicts*** whether a loan application is likely to be approved or rejected based on applicant and loan characteristics.
#
# *We are predicting.*
#
# *That immediately tells us the type of problem.*

# %% [markdown]
# # **Business Objective**
#
# The objective is to:
#
# - Improve the speed of loan processing.
# - Support consistent lending decisions.
# - Reduce credit risk.
# - Improve customer experience by reducing waiting times.
# - Assist loan officers rather than replace them.
#
# This last point is important. In banking, models often support human decision-making rather than making fully automated decisions.

# %% [markdown]
# # **How can we use Machine Learning to solve the Problem?**
#
# *Now we translate the business problem into a machine learning problem.*
#
# Target Variable is "loan_status"
#
# This is what we want to predict.
#
# For example:
#
# Approved/Rejected or perhaps
#
# 1 = Approved
#
# 0 = Rejected
#
# *We'll verify the exact values later during EDA.*

# %% [markdown]
# # **Success Criteria**
# **How does success look like?**
#
# For example:
#
# **Business metrics:**
#
# - Reduce loan processing time.
# - Improve consistency.
# - Reduce high-risk approvals.
#
# **Technical metrics:**
#
# - Precision
# - Recall
# - F1-score
# - ROC-AUC
#
# Depending on the business objective, we might prioritize recall (to identify as many risky applications as possible) or precision (to avoid wrongly rejecting good applicants). We'll make that decision after exploring the class distribution.

# %% [markdown]
# # **PART 2: UNDERSTANDING THE DATASET**

# %% [markdown]
# ## **Import the Dataset**

# %%
import pandas as pd

df = pd.read_csv('loan_applications.csv')
print(df.head())
# Out:
#                          application_id customer_id application_date  \
# 0  c8bf0bea-70e6-4870-9125-41b8210c527f  CUST109427       2023-04-09
# 1  91224cec-3544-4bc7-ac15-a9792da54c02  CUST106146       2023-09-23
# 2  4efcd02d-4a03-4ab7-9bd1-0ff430493d0c  CUST100674       2023-05-22
# 3  a61337d4-ba04-4a68-b492-2cb8266e6ed7  CUST106466       2024-07-09
# 4  a8d1639e-170b-41b2-826a-55c7dae38d16  CUST112319       2023-11-20
#
#         loan_type  loan_amount_requested  loan_tenure_months  \
# 0   Business Loan               604000.0                  12
# 1        Car Loan               100000.0                 240
# 2  Education Loan               431000.0                  60
# 3        Car Loan               324000.0                 120
# 4   Personal Loan               100000.0                  36
#
#    interest_rate_offered     purpose_of_loan employment_status  \
# 0                  11.66   Medical Emergency           Retired
# ...

# %%
df.describe()
# Out:
#        loan_amount_requested  loan_tenure_months  interest_rate_offered  \
# count           5.000000e+04          50000.0000           50000.000000
# mean            5.139130e+05            121.3884              10.528547
# std             2.752126e+05            121.4104               1.926442
# min             1.000000e+05             12.0000               7.000000
# 25%             3.000000e+05             24.0000               9.150000
# 50%             5.030000e+05             60.0000              10.510000
# 75%             7.010000e+05            240.0000              11.850000
# max             1.618000e+06            360.0000              19.620000
#
#        monthly_income   cibil_score  existing_emis_monthly  \
# count    50000.000000  50000.000000             50000.0000
# mean     50844.940000    699.149760              3066.3620
# std      23874.742237     49.920325              1896.9745
# min      10000.000000    476.000000                 0.0000
# ...

# %%
print("Tshepiso")
# Out:
# Tshepiso

# %% [markdown]
# # **What Type of Machine Learning is This?**
#
# This is Supervised Learning because:
#
# - We have historical data.
# - We know the correct outcome (loan_status).
# - The model learns from labelled examples.

# %% [markdown]
# The project was developed to address a lending decision problem in retail banking. The objective was to build a supervised machine learning classification model that predicts whether a loan application is likely to be approved based on applicant characteristics such as income, credit score, debt-to-income ratio, employment status, and loan details. The goal was not to replace loan officers but to support faster, more consistent, and data-driven lending decisions while helping the bank manage credit risk and improve customer experience."
